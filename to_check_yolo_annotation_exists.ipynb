# %%
import os ,time
from PIL import Image
import os,time
import imghdr
import shutil

# %%
cwd = os.getcwd()
print("current directory is   %s"%(cwd))
img_dir = "/home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Images/001/"            # where images are 
img_list_dir = "/home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Images/"                # where to create image list
img_list_file = img_list_dir + 'imageset_001.txt'   #image list file name
annotation_dir = "/home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/" #where annotation is 
img_without_bb_dir = "/home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Images/without_txt/"# where to move images without bb
#img_with_bb_dir = "/home/rahul/ActiveShuttle/AGV_Dataset/carton/with_bb/"# where to move images with bb
print("List of all images will be created in file  %s"%(img_list_file))
# Out:
# current directory is   /home/rahul/ActiveShuttle/image_processing
# List of all images will be created in file  /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Images/imageset_001.txt

# %% [markdown]
# # Create list of all images in a directory

# %%
img_list = open(img_list_file, 'w')
i=0

for file in os.listdir(img_dir):
    #print(file)
    try:
        i = i+1
        img_list.write('%s\n'%(file))
        #print("%s%s"%(file,i))
    except :
            print("error writing file")
            
img_list.close()
#img_list = open(img_list_file, 'r')
#print(img_list.read())

print("Number of images in %s is \n : %s"%(img_dir,i))
# Out:
# Number of images in /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Images/001/ is
#  : 104

# %%
image_ids = open(img_list_file).read().strip().split()
print("Number of images in the image list in %s is %s " %(img_list_file , len(image_ids)))
# Out:
# Number of images in the image list in /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Images/imageset_001.txt is 104

# %%
#print("Matching annotations in %s with images in %s" %(annotation_dir,img_dir))
for image_id in image_ids:
    
  annotation_id = image_id.replace(".jpg",".txt")
  print (image_id)
  annotation_file = os.path.join('%s%s' % (annotation_dir,annotation_id))
  print("searching for %s" %(annotation_file))
  exists = os.path.isfile(annotation_file)
  currentFile=os.path.join('%s%s' % (img_dir,image_id))
  #new_file_name=img_with_bb_dir + image_id
  #if exists:
       #print("exists")
  if (exists != 1):
      #print("No annotation file named %s found at %s" %(annotation_id , annotation_dir))
      new_file_name = img_without_bb_dir + image_id
      #currentFile=os.path.join('%s%s' % (img_dir,image_id))
      #print(currentFile)
      #print(os.path.basename(image_id))
      #new_file_name=img_without_bb_dir + image_id
      #print(new_file_name)
      print("No bounding box available , moving to dir: " + new_file_name)
      if not os.path.exists(img_without_bb_dir):
          os.makedirs(img_without_bb_dir)
      try:
          os.rename(currentFile, new_file_name)   #to move file 
          #shutil.copyfile(currentFile, new_file_name) #to copy file
          print("COPIED")
          n_without_bb = n_without_bb + 1
      except :
             print("error moving an image without boundingbox ")
#print("Remaining images with bounding boxe = %d" %(len(image_ids)-n_without_bb))
# Out:
# person_005.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_005.txt
# person_034.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_034.txt
# person_053.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_053.txt
# person_063.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_063.txt
# person_101.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_101.txt
# person_119.jpeg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_119.jpeg
# No bounding box available , moving to dir: /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Images/without_txt/person_119.jpeg
# error moving an image without boundingbox
# person_071.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_071.txt
# person_055.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_055.txt
# person_062.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_062.txt
# person_126.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_126.txt
# person_061.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_061.txt
# person_043.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_043.txt
# person_038.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_038.txt
# person_130.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_130.txt
# person_123.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_123.txt
# person_072.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_072.txt
# person_109.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_109.txt
# person_007.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_007.txt
# person_017.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_017.txt
# person_035.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_035.txt
# person_090.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_090.txt
# person_078.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_078.txt
# person_050.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_050.txt
# person_095.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_095.txt
# person_087.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_087.txt
# person_111.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_111.txt
# person_076.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_076.txt
# person_113.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_113.txt
# person_057.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_057.txt
# person_049.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_049.txt
# person_030.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_030.txt
# person_084.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_084.txt
# person_056.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_056.txt
# person_042.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_042.txt
# person_033.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_033.txt
# person_036.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_036.txt
# person_102.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_102.txt
# person_002.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_002.txt
# person_077.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_077.txt
# person_114.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_114.txt
# person_093.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_093.txt
# person_106.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_106.txt
# person_082.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_082.txt
# person_091.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_091.txt
# person_051.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_051.txt
# person_011.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_011.txt
# person_018.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_018.txt
# person_029.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_029.txt
# person_040.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_040.txt
# person_088.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_088.txt
# person_015.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_015.txt
# person_064.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_064.txt
# person_028.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_028.txt
# person_103.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_103.txt
# person_010.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_010.txt
# person_115.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_115.txt
# person_041.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_041.txt
# person_054.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_054.txt
# person_118.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_118.txt
# person_066.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_066.txt
# person_006.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_006.txt
# person_047.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_047.txt
# person_125.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_125.txt
# person_092.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_092.txt
# person_024.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_024.txt
# person_031.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_031.txt
# person_069.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_069.txt
# person_070.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_070.txt
# person_089.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_089.txt
# person_058.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_058.txt
# person_008.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_008.txt
# person_045.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_045.txt
# person_065.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_065.txt
# person_023.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_023.txt
# person_044.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_044.txt
# person_098.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_098.txt
# person_019.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_019.txt
# person_016.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_016.txt
# person_013.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_013.txt
# person_131.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_131.txt
# person_067.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_067.txt
# person_009.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_009.txt
# person_122.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_122.txt
# person_083.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_083.txt
# person_039.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_039.txt
# person_022.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_022.txt
# person_120.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_120.txt
# person_025.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_025.txt
# person_079.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_079.txt
# person_046.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_046.txt
# person_068.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_068.txt
# person_094.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_094.txt
# person_127.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_127.txt
# person_075.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_075.txt
# person_052.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_052.txt
# person_059.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_059.txt
# person_085.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_085.txt
# person_032.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_032.txt
# person_133.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_133.txt
# person_060.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_060.txt
# person_074.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_074.txt
# person_004.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_004.txt
# person_027.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_027.txt
# person_129.jpg
# searching for /home/rahul/ActiveShuttle/Manivannan_yolo/YOLO-Annotation-Tool/Labels/output/person_129.txt
