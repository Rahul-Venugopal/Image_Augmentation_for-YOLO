# %% [markdown]
# # Import required libraries

# %%
import os ,time

# %% [markdown]
# # Define all paths

# %%
cwd = os.getcwd()
print("current directory is   %s"%(cwd))
img_dir = "/home/rahul/ActiveShuttle/AGV_Dataset/forklift/n03384352/"            # where images are 
img_list_dir = "/home/rahul/ActiveShuttle/AGV_Dataset/forklift/"                # where to create image list
img_list_file = img_list_dir + 'imageset.txt'                                   #image list file name
annotation_dir = "/home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/" #where annotation is 
img_without_bb_dir = "/home/rahul/ActiveShuttle/AGV_Dataset/forklift/without_bb/"# where to move images without bb
img_with_bb_dir = "/home/rahul/ActiveShuttle/AGV_Dataset/forklift/with_bb/"# where to move images with bb
print("List of all images will be created in file  %s"%(img_list_file))
# Out:
# current directory is   /home/rahul/ActiveShuttle/yolov3_Activeshuttle
# List of all images will be created in file  /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imageset.txt

# %% [markdown]
# # Create list of all images in a directory

# %%
img_list = open(img_list_file, 'w')
i=0

for file in os.listdir(img_dir):
    #print(file)
    try:
        i = i+1
        img_list.write('%s\n'%(file))
        #print("%s%s"%(file,i))
    except :
            print("error writing file")
            
image_list.close()
#img_list = open(img_list_file, 'r')
#print(img_list.read())

print("Number of images in %s is \n : %s"%(img_dir,i))
# Out:
# Number of images in /home/rahul/ActiveShuttle/AGV_Dataset/forklift/n03384352/ is
#  : 748

# %% [markdown]
# # Remove Images without bounding box information

# %%
image_ids = open(img_list_file).read().strip().split()
print("Number of images in the image list is %s " %(len(image_ids)))
n_without_bb = 0   # flag for counting images without bb
n_with_bb = 0      # # flag for counting images with bb
# Out:
# Number of images in the image list is 748

# %%
for image_id in image_ids:
    
  annotation_id = image_id.replace(".jpg",".xml")
  print (image_id)
  annotation_file = os.path.join('%s%s' % (annotation_dir,annotation_id))
  print("searching for %s" %(annotation_file))
  exists = os.path.isfile(annotation_file)
  currentFile=os.path.join('%s%s' % (img_dir,image_id))
  #new_file_name=img_with_bb_dir + image_id
  if exists:
      #print("Annotation exists")
      new_file_name=img_with_bb_dir + image_id
      print("Annotation_Exists , moving to dir: " + new_file_name)
      if not os.path.exists(img_with_bb_dir):
          os.makedirs(img_with_bb_dir)
      try:
          os.rename(currentFile, new_file_name)
          print("moved")
          n_with_bb = n_with_bb + 1
          #print("here is the problem")
      except:
            print("error moving an image with bounding box")
  else:
      print("No annotation file named %s found at %s" %(annotation_id , annotation_dir))
      new_file_name = move_to_dir + image_id
      #currentFile=os.path.join('%s%s' % (img_dir,image_id))
      #print(currentFile)
      #print(os.path.basename(image_id))
      #new_file_name=img_without_bb_dir + image_id
      #print(new_file_name)
      print("No bounding box available , moving to dir: " + new_file_name)
      if not os.path.exists(move_to_dir):
          os.makedirs(img_without_bb_dir)
      try:
          os.rename(currentFile, new_file_name)
          print("moved")
          n_without_bb = n_without_bb + 1
      except :
             print("error moving an image without boundingbox ")
#print("Remaining images with bounding boxe = %d" %(len(image_ids)-n_without_bb))
# Out:
# n03384352_5953.jpg
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_5953.xml
# Annotation_Exists , moving to dir: /home/rahul/ActiveShuttle/AGV_Dataset/forklift/with_bb/n03384352_5953.jpg
# moved
# here is the problem
# n03384352_4709.jpg
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_4709.xml
# No annotation file named n03384352_4709.xml found at /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/
# No bounding box available , moving to dir: /home/rahul/ActiveShuttle/AGV_Dataset/forklift/without_bb/n03384352_4709.jpg
# moved
# n03384352_11271.jpg
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_11271.xml
# Annotation_Exists , moving to dir: /home/rahul/ActiveShuttle/AGV_Dataset/forklift/with_bb/n03384352_11271.jpg
# moved
# here is the problem
# n03384352_2038.jpg
# ...

# %%
print("number of images with bb : \n %s" %n_with_bb)
print("number of images without bb : \n %s" %n_without_bb)
# Out:
# number of images with bb :
#  250
# number of images without bb :
#  498

# %% [markdown]
# # End of this Section

# %%
for image_id in image_ids:
    
  annotation_id = image_id.replace(".jpg",".xml")
  print (image_id)
  print(annotation_id)
  annotation_file = os.path.join(annotation_dir,annotation_id)
  print("searching for %s" %(annotation_file))
  exists = os.path.isfile("%s%s"%(annotation_dir,annotation_id))
  #exists = os.path.isfile("%s"%(annotation_id))
  #exists = os.path.isfile("%s%s" %((os.path.expandvars(annotation_dir)) , annotation_id))
  #os.path.expandvars(fileName)
  #if os.path.exists(annotation_dir + annotation_id) :
  if exists:  
           print("True")
# Out:
# n03384352_5953.jpg
# n03384352_5953.xml
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_5953.xml
# True
# n03384352_4709.jpg
# n03384352_4709.xml
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_4709.xml
# n03384352_11271.jpg
# n03384352_11271.xml
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_11271.xml
# True
# n03384352_2038.jpg
# n03384352_2038.xml
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_2038.xml
# n03384352_1556.jpg
# n03384352_1556.xml
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_1556.xml
# n03384352_9197.jpg
# n03384352_9197.xml
# searching for /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_9197.xml
# n03384352_7121.jpg
# n03384352_7121.xml
# ...

# %%
annotation_id = "n03384352_27.xml"
#loc = "/home/rahul/ActiveShuttle/yolov3_Activeshuttle/Annotation/"
loc_dir = "/home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/"
#print(abc)
exists = os.path.isfile("%s%s" %(loc_dir,annotation_id))
print(exists)
# Out:
# True

# %%
for image_id in image_ids:
    
  annotation_id = image_id.replace(".jpg",".xml")
  print (image_id)
  annotation_file = os.path.join('%s%s' % (annotation_dir,annotation_id))
  print("searching for %s" %(annotation_file))
  exists = os.path.isfile(annotation_file)
  if exists:
      print("Annotation exists")
  else:
      print("No annotation file named %s found at %s" %(annotation_id , annotation_dir))
      #new_file_name = move_to_dir + image_id
      currentFile=os.path.join('%s%s' % (img_dir,image_id))
#print(currentFile)
#print(os.path.basename(image_id))
      new_file_name=move_to_dir + image_id
#print(new_file_name)
      print("No bounding box available , moving to dir: " + new_file_name)
      if not os.path.exists(move_to_dir):
          os.makedirs(move_to_dir)
      try:
          os.rename(currentFile, new_file_name)
          print("moved")
      except :
             print("error moving file")
# Out:
# n03384352_5953.jpg
# searching for  /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_5953.xml
# No annotation file named n03384352_5953.xml found at  /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/
# No bounding box available , moving to dir: /home/rahul/ActiveShuttle/AGV_Dataset/forklift/without_bb/n03384352_5953.jpg
# moved
# n03384352_4709.jpg
# searching for  /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_4709.xml
# No annotation file named n03384352_4709.xml found at  /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/
# No bounding box available , moving to dir: /home/rahul/ActiveShuttle/AGV_Dataset/forklift/without_bb/n03384352_4709.jpg
# moved
# n03384352_11271.jpg
# searching for  /home/rahul/ActiveShuttle/AGV_Dataset/forklift/imagenet_bb/n03384352/n03384352_11271.xml
# ...

# %%
currentFile=os.path.join('/home/rahul/ActiveShuttle/AGV_Dataset/forklift/%s' % (image_id))
print(currentFile)
print(os.path.basename(image_id))
new_file_name=move_to_dir + image_id
print(new_file_name)
print("No bounding box available , moving to dir: "+new_file_name)
if not os.path.exists(move_to_dir):
    os.makedirs(move_to_dir)
    try:
        os.rename(currentFile, new_file_name)
    except WindowsError:
        print("error moving file")
# Out:
# /home/rahul/ActiveShuttle/AGV_Dataset/forklift/n03384352_52.jpg
# n03384352_52.jpg
# /home/rahul/ActiveShuttle/AGV_Dataset/forklift/without_bb/n03384352_52.jpg
# No bounding box available , moving to dir: /home/rahul/ActiveShuttle/AGV_Dataset/forklift/without_bb/n03384352_52.jpg
